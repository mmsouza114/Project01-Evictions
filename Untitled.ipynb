# %%
import pandas as pd

# %%
## import the new cleaned data set
df = pd.read_csv("cleaned_evictions_df.csv")
df.head()
# Out:
#    Docket_Number_         Eviction_Address Executed_Date Property_Type  \
# 0          352435     319 WEST 94TH STREET    2019-03-25   Residential
# 1          379048         2332 CRESTON AVE    2017-04-25   Residential
# 2          320691   2670 BAINBRIDGE AVENUE    2017-02-21   Residential
# 3          115775          18-24 25TH ROAD    2019-04-23   Residential
# 4           86395  3005 EASTCHESTER  RO AD    2018-11-08    Commercial
#
#      Borough  Eviction_Postcode         Ejectment Eviction/Legal_Possession  \
# 0  MANHATTAN              10025  Not an Ejectment                Possession
# 1      BRONX              10468  Not an Ejectment                Possession
# 2      BRONX              10458  Not an Ejectment                Possession
# 3     QUEENS              11102  Not an Ejectment                Possession
# 4      BRONX              10469  Not an Ejectment                Possession
#
#     Latitude   Longitude Community_Board Council_District Census_Tract  \
# ...

# %% [markdown]
# ## I noticed that I have some values in some columns that don't match the rest of the columns type. I want to change that.

# %% [markdown]
# Let's start by checking the info on the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67184 entries, 0 to 67183
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Docket_Number_                67184 non-null  int64
#  1   Eviction_Address              67184 non-null  object
#  2   Executed_Date                 67184 non-null  object
#  3   Property_Type                 67184 non-null  object
#  4   Borough                       67184 non-null  object
#  5   Eviction_Postcode             67184 non-null  int64
#  6   Ejectment                     67184 non-null  object
#  7   Eviction/Legal_Possession     67184 non-null  object
#  8   Latitude                      67184 non-null  object
#  9   Longitude                     67184 non-null  object
#  10  Community_Board               67184 non-null  object
#  11  Council_District              67184 non-null  object
# ...

# %%
df.isin(['Not Provided']).any()
# Out:
# Docket_Number_                  False
# Eviction_Address                False
# Executed_Date                   False
# Property_Type                   False
# Borough                         False
# Eviction_Postcode               False
# Ejectment                       False
# Eviction/Legal_Possession       False
# Latitude                         True
# Longitude                        True
# Community_Board                  True
# Council_District                 True
# Census_Tract                     True
# Neighborhood_Tabulation_Area     True
# Year                            False
# Month                           False
# dtype: bool

# %%
df[df['Latitude']== 'Not Provided']
# Out:
#        Docket_Number_                                   Eviction_Address  \
# 25              33234             39-19 103RD STREET OFFICE FOR TAX PREP
# 29               7316               62-08 MYRTLE AVENUE  FRONT APARTMENT
# 35             152860                   1094 LENOX ROAD (1ST.FLR ENTIRE)
# 70              79746                      359 FORT   WASHINGTO N AVENUE
# 73               4957               445 AMBOY STREET APT.  RM 1 BASEMENT
# ...               ...                                                ...
# 67132           12156                   142-06 185TH STREET ENTIRE HOUSE
# 67156          100471    11 VARICK STREET (A/ K/A 16 NORTH MOORE STREET)
# 67161            9415                     431 HERZL ST - APT 1F (1ST FL)
# 67169           99309                           1955 RICHMOND   TERR ACE
# 67171           12034  153 EIGHTH AVENUE - NORTHERNMOST STORE & PORTI...
#
#       Executed_Date Property_Type        Borough  Eviction_Postcode  \
# ...
