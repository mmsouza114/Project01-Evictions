# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#evictions_df = pd.read_csv("Evictions.csv")
evictions_df = pd.read_csv('Evictions.csv', index_col=0, parse_dates=[4])

evictions_df.head()
#evictions_df.info()
# Out:
#                     Docket Number          Eviction Address  \
# Court Index Number
# 50365/19                    352435     319 WEST 94TH STREET
# B068159/16                  379048         2332 CRESTON AVE
# 59891/16                    320691   2670 BAINBRIDGE AVENUE
# 75708/18                    115775          18-24 25TH ROAD
# 900940/18                    86395  3005 EASTCHESTER  RO AD
#
#                    Eviction Apartment Number Executed Date Marshal First Name  \
# Court Index Number
# 50365/19                                C103    2019-03-25             Thomas
# B068159/16                                41    2017-04-25            Richard
# 59891/16                                  2F    2017-02-21               John
# 75708/18                                   1    2019-04-23             Maxine
# 900940/18                         STOREFRONT    2018-11-08             Justin
#
#                    Marshal Last Name Residential/Commercial    BOROUGH  \
# ...

# %%
evictions_df.shape
# Out:
# (67728, 19)

# %%
evictions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 67728 entries, 50365/19 to 20290/16
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Docket Number              67728 non-null  int64
#  1   Eviction Address           67728 non-null  object
#  2   Eviction Apartment Number  56519 non-null  object
#  3   Executed Date              67728 non-null  datetime64[ns]
#  4   Marshal First Name         67728 non-null  object
#  5   Marshal Last Name          67728 non-null  object
#  6   Residential/Commercial     67728 non-null  object
#  7   BOROUGH                    67728 non-null  object
#  8   Eviction Postcode          67728 non-null  int64
#  9   Ejectment                  67728 non-null  object
#  10  Eviction/Legal Possession  67728 non-null  object
#  11  Latitude                   61284 non-null  float64
#  12  Longitude                  61284 non-null  float64
# ...

# %%
#replacing spaces in the data sheet column names
evictions_df.columns = evictions_df.columns.str.replace(' ','_')
#print info again to see the changes to the columns names
evictions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 67728 entries, 50365/19 to 20290/16
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Docket_Number_             67728 non-null  int64
#  1   Eviction_Address           67728 non-null  object
#  2   Eviction_Apartment_Number  56519 non-null  object
#  3   Executed_Date              67728 non-null  datetime64[ns]
#  4   Marshal_First_Name         67728 non-null  object
#  5   Marshal_Last_Name          67728 non-null  object
#  6   Residential/Commercial     67728 non-null  object
#  7   BOROUGH                    67728 non-null  object
#  8   Eviction_Postcode          67728 non-null  int64
#  9   Ejectment                  67728 non-null  object
#  10  Eviction/Legal_Possession  67728 non-null  object
#  11  Latitude                   61284 non-null  float64
#  12  Longitude                  61284 non-null  float64
# ...

# %%
pd.set_option("display.max_rows", None)
#returns a list of all the evictions that occurred on the eviction address "541 WEST 29TH STREET" which showed
#to have 71 duplicates
pd.DataFrame(evictions_df.where(evictions_df['Eviction_Address']=='541 WEST 29TH STREET').dropna())
# Out:
#                     Docket_Number_      Eviction_Address  \
# Court Index Number
# 69121/18                  347777.0  541 WEST 29TH STREET
# 69120/18                  347780.0  541 WEST 29TH STREET
# 53174/19                  352822.0  541 WEST 29TH STREET
# 63503/18                  346075.0  541 WEST 29TH STREET
# 60155/17                  333887.0  541 WEST 29TH STREET
# 63256/19                  355568.0  541 WEST 29TH STREET
# 65411/17                  335457.0  541 WEST 29TH STREET
# 56233/19                  353616.0  541 WEST 29TH STREET
# 69117/18                  347785.0  541 WEST 29TH STREET
# 69950/17                  337061.0  541 WEST 29TH STREET
# 76892/17                  339303.0  541 WEST 29TH STREET
# 60157/17                  333886.0  541 WEST 29TH STREET
# 73671/17                  338106.0  541 WEST 29TH STREET
# 53169/19                  352820.0  541 WEST 29TH STREET
# 69949/17                  337062.0  541 WEST 29TH STREET
# ...

# %%
#pd.set_option("display.max_rows", None)
#evictions_df.pivot_table(index=['Eviction_Address'], aggfunc='size')

# %%
#stores data file into DataFrame and retreive the duplicates from only column Eviction_Address that over 20 or over
#But also shows all the address that are not as NaN

#dupps = pd.DataFrame(evictions_df['Eviction_Address'].value_counts())
#dupps.index.dropna()
#dupps[dupps > 20]

# %%
#Shows only the address that are 20 over duplicated and drops all the others from the list

#dupps = pd.DataFrame(evictions_df['Eviction_Address'].value_counts(dropna=True).loc[lambda x : x>=20])
#print(dupps.count())
#print(dupps)

# %%
#dupps = pd.DataFrame(evictions_df['Eviction_Address'].value_counts(dropna=True).loc[lambda x : x>=20])
#print(dupps.count())
#print(dupps)

# %%
#Gives me the matching address only with its count of duplicates

#addy1 = pd.DataFrame(evictions_df['Eviction_Address'].where(evictions_df['Eviction_Address']=='541 WEST 29TH STREET').value_counts(dropna=True))
#print(addy1)

# %%
#addy1 = evictions_df[evictions_df['Eviction_Address']=='541 WEST 29TH STREET']
#print(addy1)

# %%
#pd.DataFrame(evictions_df[['Eviction_Address','Executed_Date','Docket_Number_','Eviction_Apartment_Number','Residential/Commercial']].where(evictions_df['Eviction_Address']=='541 WEST 29TH STREET').value_counts(dropna=True).loc[(evictions_df['Executed_Date'] >= '2021-01-01')& (evictions_df['Executed_Date'] < '2021-12-01')])
#work in progress will result in error
