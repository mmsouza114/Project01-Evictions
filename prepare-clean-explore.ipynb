# %% [markdown]
# # Preparing the dataset and cleaning it up with Pandas

# %% [markdown]
# ### First let's import pandas API

# %%
import pandas as pd

# %% [markdown]
# ### Now let's read in our csv data file

# %%
df = pd.read_csv("Evictions.csv")
df = pd.read_csv('Evictions.csv', index_col=0, parse_dates=[4])

#this will show me the first 10 rows in the data sheet
df.head(10)
# Out:
#                     Docket Number          Eviction Address  \
# Court Index Number
# 50365/19                    352435     319 WEST 94TH STREET
# B068159/16                  379048         2332 CRESTON AVE
# 59891/16                    320691   2670 BAINBRIDGE AVENUE
# 75708/18                    115775          18-24 25TH ROAD
# 900940/18                    86395  3005 EASTCHESTER  RO AD
# Q75179/18                    97002        153-12 FOCH BLVD.
# 59927/18                     17756       156-43 79TH STREET
# 61859/19                     95620         2301 65TH STREET
# 63989/17                     23118     1 BEACH 105TH STREET
# 52272/18                    350225           65 JESUP PLACE
#
#                    Eviction Apartment Number Executed Date Marshal First Name  \
# Court Index Number
# 50365/19                                C103    2019-03-25             Thomas
# B068159/16                                41    2017-04-25            Richard
# 59891/16                                  2F    2017-02-21               John
# 75708/18                                   1    2019-04-23             Maxine
# 900940/18                         STOREFRONT    2018-11-08             Justin
# Q75179/18                      PRIVATE HOUSE    2019-07-12             Ileana
# 59927/18                                 NaN    2019-02-25             Edward
# 61859/19                                  3D    2019-06-14              Henry
# 63989/17                                  3D    2018-01-08               Gary
# 52272/18                                   B    2019-03-27             Thomas
#
#                    Marshal Last Name Residential/Commercial    BOROUGH  \
# Court Index Number
# 50365/19                         Bia            Residential  MANHATTAN
# B068159/16                     McCoy            Residential      BRONX
# 59891/16                  Villanueva            Residential      BRONX
# 75708/18                    Chevlowe            Residential     QUEENS
# 900940/18                   Grossman             Commercial      BRONX
# Q75179/18                     Rivera            Residential     QUEENS
# 59927/18                       Guida            Residential     QUEENS
# 61859/19                       Daley            Residential   BROOKLYN
# 63989/17                        Rose            Residential     QUEENS
# 52272/18                         Bia            Residential      BRONX
#
#                     Eviction Postcode         Ejectment  \
# Court Index Number
# 50365/19                        10025  Not an Ejectment
# B068159/16                      10468  Not an Ejectment
# 59891/16                        10458  Not an Ejectment
# 75708/18                        11102  Not an Ejectment
# 900940/18                       10469  Not an Ejectment
# Q75179/18                       11434  Not an Ejectment
# 59927/18                        11414  Not an Ejectment
# 61859/19                        11204  Not an Ejectment
# 63989/17                        11694  Not an Ejectment
# 52272/18                        10452  Not an Ejectment
#
#                    Eviction/Legal Possession   Latitude  Longitude  \
# Court Index Number
# 50365/19                          Possession  40.794205 -73.974734
# B068159/16                        Possession  40.858643 -73.900402
# 59891/16                          Possession  40.865470 -73.891472
# 75708/18                          Possession  40.774861 -73.926140
# 900940/18                         Possession  40.869607 -73.842766
# Q75179/18                         Possession  40.681478 -73.789636
# 59927/18                          Possession  40.661535 -73.854088
# 61859/19                          Possession  40.612436 -73.979088
# 63989/17                          Possession  40.581498 -73.825268
# 52272/18                          Possession  40.842213 -73.920384
#
#                     Community Board  Council District  Census Tract  \
# Court Index Number
# 50365/19                        7.0               6.0         183.0
# B068159/16                      5.0              14.0       23703.0
# 59891/16                        7.0              15.0       40502.0
# 75708/18                        1.0              22.0          91.0
# 900940/18                      12.0              12.0         358.0
# Q75179/18                      12.0              28.0         288.0
# 59927/18                       10.0              32.0        6202.0
# 61859/19                       11.0              44.0         436.0
# 63989/17                       14.0              32.0         938.0
# 52272/18                        4.0              16.0       21302.0
#
#                           BIN           BBL  \
# Court Index Number
# 50365/19            1034178.0  1.012530e+09
# B068159/16          2013777.0  2.031640e+09
# 59891/16            2016620.0  2.032870e+09
# 75708/18            4019956.0  4.008870e+09
# 900940/18           2061802.0  2.047620e+09
# Q75179/18           4264878.0  4.122040e+09
# 59927/18            4448225.0  4.139428e+09
# 61859/19            3172477.0  3.065590e+09
# 63989/17            4303819.0  4.161770e+09
# 52272/18            2008687.0  2.028720e+09
#
#                                                                   NTA
# Court Index Number
# 50365/19                                              Upper West Side
# B068159/16                                              Fordham South
# 59891/16                                   Bedford Park-Fordham North
# 75708/18                                                  Old Astoria
# 900940/18                             Eastchester-Edenwald-Baychester
# Q75179/18                                                Baisley Park
# 59927/18                                      Lindenwood-Howard Beach
# 61859/19                                             Bensonhurst East
# 63989/17            Breezy Point-Belle Harbor-Rockaway Park-Broad ...
# 52272/18                                                   Highbridge

# %% [markdown]
# ### Next I am going to display some info on my dataset to get a better idea of what I am working with

# %%
#Show a list of columns for easier refernce to check which ones I am interested in
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 67728 entries, 50365/19 to 20290/16
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Docket Number              67728 non-null  int64
#  1   Eviction Address           67728 non-null  object
#  2   Eviction Apartment Number  56519 non-null  object
#  3   Executed Date              67728 non-null  datetime64[ns]
#  4   Marshal First Name         67728 non-null  object
#  5   Marshal Last Name          67728 non-null  object
#  6   Residential/Commercial     67728 non-null  object
#  7   BOROUGH                    67728 non-null  object
#  8   Eviction Postcode          67728 non-null  int64
#  9   Ejectment                  67728 non-null  object
#  10  Eviction/Legal Possession  67728 non-null  object
#  11  Latitude                   61284 non-null  float64
#  12  Longitude                  61284 non-null  float64
#  13  Community Board            61284 non-null  float64
#  14  Council District           61284 non-null  float64
#  15  Census Tract               61284 non-null  float64
#  16  BIN                        61166 non-null  float64
#  17  BBL                        61166 non-null  float64
#  18  NTA                        61284 non-null  object
# dtypes: datetime64[ns](1), float64(7), int64(2), object(9)
# memory usage: 10.3+ MB

# %%
#Now to delete the ones I am not interested in 
#First lets use the columns function to make it easier to delete the ones I dont need
df.columns
# Out:
# Index(['Court Index Number', 'Docket Number ', 'Eviction Address',
#        'Eviction Apartment Number', 'Executed Date', 'Marshal First Name',
#        'Marshal Last Name', 'Residential/Commercial', 'BOROUGH',
#        'Eviction Postcode', 'Ejectment', 'Eviction/Legal Possession',
#        'Latitude', 'Longitude', 'Community Board', 'Council District',
#        'Census Tract', 'BIN', 'BBL', 'NTA'],
#       dtype='object')

# %%
evictions_df_subset= evictions_df[['Court Index Number', 'Docket Number ', 'Eviction Address',
       'Eviction Apartment Number', 'Executed Date', 'Marshal First Name',
       'Marshal Last Name', 'Residential/Commercial', 'BOROUGH',
       'Eviction Postcode', 'Ejectment', 'Eviction/Legal Possession',
       'Latitude', 'Longitude', 'Community Board', 'Council District',
       'Census Tract', 'BIN', 'BBL', 'NTA']]
evictions_df_subset
# Out:
#       Court Index Number  Docket Number          Eviction Address  \
# 0               50365/19          352435     319 WEST 94TH STREET
# 1             B068159/16          379048         2332 CRESTON AVE
# 2               59891/16          320691   2670 BAINBRIDGE AVENUE
# 3               75708/18          115775          18-24 25TH ROAD
# 4              900940/18           86395  3005 EASTCHESTER  RO AD
# ...                  ...             ...                      ...
# 67723         R 50452/17           68450     182 ARLINGTON AVENUE
# 67724          N66489/17           81749   600 WEST 136TH STREE T
# 67725         60675/17-1          208636         115 LINCOLN ROAD
# 67726          B42335/17           83318  1131-1133 OGDEN AVEN UE
# 67727           20290/16           59510             5 FLEET WALK
#
#       Eviction Apartment Number Executed Date Marshal First Name  \
# 0                          C103    03/25/2019             Thomas
# 1                            41    04/25/2017            Richard
# 2                            2F    02/21/2017               John
# 3                             1    04/23/2019             Maxine
# 4                    STOREFRONT    11/08/2018             Justin
# ...                         ...           ...                ...
# 67723                       NaN    03/29/2017             Steven
# 67724                        6F    09/27/2017             Ileana
# 67725                        3N    01/09/2020            Richard
# 67726                       12A    12/13/2017             Ileana
# 67727                       08E    08/02/2017             Justin
#
#       Marshal Last Name Residential/Commercial        BOROUGH  \
# 0                   Bia            Residential      MANHATTAN
# 1                 McCoy            Residential          BRONX
# 2            Villanueva            Residential          BRONX
# 3              Chevlowe            Residential         QUEENS
# 4              Grossman             Commercial          BRONX
# ...                 ...                    ...            ...
# 67723            Powell            Residential  STATEN ISLAND
# 67724            Rivera            Residential      MANHATTAN
# 67725           Capuano            Residential       BROOKLYN
# 67726            Rivera            Residential          BRONX
# 67727          Grossman            Residential       BROOKLYN
#
#        Eviction Postcode         Ejectment Eviction/Legal Possession  \
# 0                  10025  Not an Ejectment                Possession
# 1                  10468  Not an Ejectment                Possession
# 2                  10458  Not an Ejectment                Possession
# 3                  11102  Not an Ejectment                Possession
# 4                  10469  Not an Ejectment                Possession
# ...                  ...               ...                       ...
# 67723              10303  Not an Ejectment                Possession
# 67724              10031  Not an Ejectment                Possession
# 67725              11225  Not an Ejectment                Possession
# 67726              10452  Not an Ejectment                Possession
# 67727              11201  Not an Ejectment                Possession
#
#         Latitude  Longitude  Community Board  Council District  Census Tract  \
# 0      40.794205 -73.974734              7.0               6.0         183.0
# 1      40.858643 -73.900402              5.0              14.0       23703.0
# 2      40.865470 -73.891472              7.0              15.0       40502.0
# 3      40.774861 -73.926140              1.0              22.0          91.0
# 4      40.869607 -73.842766             12.0              12.0         358.0
# ...          ...        ...              ...               ...           ...
# 67723  40.635485 -74.167531              1.0              49.0         323.0
# 67724  40.820935 -73.954996              9.0               7.0       22301.0
# 67725  40.661077 -73.958799              9.0              40.0       79801.0
# 67726  40.836286 -73.927496              4.0              16.0         199.0
# 67727  40.695529 -73.981230              2.0              35.0          15.0
#
#              BIN           BBL  \
# 0      1034178.0  1.012530e+09
# 1      2013777.0  2.031640e+09
# 2      2016620.0  2.032870e+09
# 3      4019956.0  4.008870e+09
# 4      2061802.0  2.047620e+09
# ...          ...           ...
# 67723  5028488.0  5.012670e+09
# 67724  1059959.0  1.020020e+09
# 67725  3379187.0  3.013270e+09
# 67726  2088158.0  2.025260e+09
# 67727  3257046.0  3.020500e+09
#
#                                                      NTA
# 0                                        Upper West Side
# 1                                          Fordham South
# 2                             Bedford Park-Fordham North
# 3                                            Old Astoria
# 4                        Eastchester-Edenwald-Baychester
# ...                                                  ...
# 67723  Mariner's Harbor-Arlington-Port Ivory-Granitev...
# 67724                                     Manhattanville
# 67725                  Prospect Lefferts Gardens-Wingate
# 67726                                         Highbridge
# 67727   DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill
#
# [67728 rows x 20 columns]

# %%
#Now lets replace the spaces between the column names with "_" so it's easier to work with
evictions_df_subset.columns = evictions_df_subset.columns.str.replace(' ','_')


evictions_df_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67728 entries, 0 to 67727
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Court_Index_Number         67728 non-null  object
#  1   Docket_Number_             67728 non-null  int64
#  2   Eviction_Address           67728 non-null  object
#  3   Eviction_Apartment_Number  56519 non-null  object
#  4   Executed_Date              67728 non-null  object
#  5   Marshal_First_Name         67728 non-null  object
#  6   Marshal_Last_Name          67728 non-null  object
#  7   Residential/Commercial     67728 non-null  object
#  8   BOROUGH                    67728 non-null  object
#  9   Eviction_Postcode          67728 non-null  int64
#  10  Ejectment                  67728 non-null  object
#  11  Eviction/Legal_Possession  67728 non-null  object
#  12  Latitude                   61284 non-null  float64
#  13  Longitude                  61284 non-null  float64
#  14  Community_Board            61284 non-null  float64
#  15  Council_District           61284 non-null  float64
#  16  Census_Tract               61284 non-null  float64
#  17  BIN                        61166 non-null  float64
#  18  BBL                        61166 non-null  float64
#  19  NTA                        61284 non-null  object
# dtypes: float64(7), int64(2), object(11)
# memory usage: 10.3+ MB

# %%
#convert date executed type object into datetime
evictions_df_subset['Executed_Date']= pd.to_datetime(evictions_df_subset['Executed_Date'])

#call info function again to double check it changed type
evictions_df_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67728 entries, 0 to 67727
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Court_Index_Number         67728 non-null  object
#  1   Docket_Number_             67728 non-null  int64
#  2   Eviction_Address           67728 non-null  object
#  3   Eviction_Apartment_Number  56519 non-null  object
#  4   Executed_Date              67728 non-null  datetime64[ns]
#  5   Marshal_First_Name         67728 non-null  object
#  6   Marshal_Last_Name          67728 non-null  object
#  7   Residential/Commercial     67728 non-null  object
#  8   BOROUGH                    67728 non-null  object
#  9   Eviction_Postcode          67728 non-null  int64
#  10  Ejectment                  67728 non-null  object
#  11  Eviction/Legal_Possession  67728 non-null  object
#  12  Latitude                   61284 non-null  float64
#  13  Longitude                  61284 non-null  float64
#  14  Community_Board            61284 non-null  float64
#  15  Council_District           61284 non-null  float64
#  16  Census_Tract               61284 non-null  float64
#  17  BIN                        61166 non-null  float64
#  18  BBL                        61166 non-null  float64
#  19  NTA                        61284 non-null  object
# dtypes: datetime64[ns](1), float64(7), int64(2), object(10)
# memory usage: 10.3+ MB

# %%
#Now let us see if there are any null values.
evictions_df_subset.isna().sum()
# Out:
# Court_Index_Number               0
# Docket_Number_                   0
# Eviction_Address                 0
# Eviction_Apartment_Number    11209
# Executed_Date                    0
# Marshal_First_Name               0
# Marshal_Last_Name                0
# Residential/Commercial           0
# BOROUGH                          0
# Eviction_Postcode                0
# Ejectment                        0
# Eviction/Legal_Possession        0
# Latitude                      6444
# Longitude                     6444
# Community_Board               6444
# Council_District              6444
# Census_Tract                  6444
# BIN                           6562
# BBL                           6562
# NTA                           6444
# dtype: int64

# %%
evictions_df_subset[evictions_df_subset['Latitude'].isna()]
# Out:
#       Court_Index_Number  Docket_Number_  \
# 25              52516/18           33234
# 29            50655/17-2            7316
# 35              63238/17          152860
# 71              53925/16           79746
# 74              98056/16            4957
# ...                  ...             ...
# 67676           61075/19           12156
# 67700          N65431/19          100471
# 67705           66060/18            9415
# 67713           51791/19           99309
# 67715           67009/19           12034
#
#                                         Eviction_Address  \
# 25                39-19 103RD STREET OFFICE FOR TAX PREP
# 29                  62-08 MYRTLE AVENUE  FRONT APARTMENT
# 35                      1094 LENOX ROAD (1ST.FLR ENTIRE)
# 71                         359 FORT   WASHINGTO N AVENUE
# 74                  445 AMBOY STREET APT.  RM 1 BASEMENT
# ...                                                  ...
# 67676                   142-06 185TH STREET ENTIRE HOUSE
# 67700    11 VARICK STREET (A/ K/A 16 NORTH MOORE STREET)
# 67705                     431 HERZL ST - APT 1F (1ST FL)
# 67713                           1955 RICHMOND   TERR ACE
# 67715  153 EIGHTH AVENUE - NORTHERNMOST STORE & PORTI...
#
#       Eviction_Apartment_Number Executed_Date Marshal_First_Name  \
# 25                          NaN    2018-09-12              Bruce
# 29                          NaN    2017-07-05             George
# 35                          NaN    2017-10-31             Ronald
# 71                           3C    2018-09-11             Justin
# 74                    BSMT RM.1    2017-04-20             Robert
# ...                         ...           ...                ...
# 67676                       NaN    2019-11-06             Robert
# 67700                        4M    2020-01-30             Ileana
# 67705                        1F    2018-11-15             Robert
# 67713                 2ND FLOOR    2020-01-17             Justin
# 67715                       NaN    2019-11-07             Robert
#
#       Marshal_Last_Name Residential/Commercial        BOROUGH  \
# 25                 Kemp             Commercial         QUEENS
# 29          Essock, Jr.            Residential         QUEENS
# 35               Pazant            Residential       BROOKLYN
# 71             Grossman            Residential      MANHATTAN
# 74             Renzulli            Residential       BROOKLYN
# ...                 ...                    ...            ...
# 67676          Renzulli            Residential         QUEENS
# 67700            Rivera            Residential      MANHATTAN
# 67705          Renzulli            Residential       BROOKLYN
# 67713          Grossman            Residential  STATEN ISLAND
# 67715          Renzulli             Commercial      MANHATTAN
#
#        Eviction_Postcode         Ejectment Eviction/Legal_Possession  \
# 25                 11368  Not an Ejectment                Possession
# 29                 11385  Not an Ejectment                Possession
# 35                 11212  Not an Ejectment                Possession
# 71                 10033  Not an Ejectment                Possession
# 74                 11212  Not an Ejectment                Possession
# ...                  ...               ...                       ...
# 67676              11413  Not an Ejectment                Possession
# 67700              10013  Not an Ejectment                Possession
# 67705              11212  Not an Ejectment                Possession
# 67713              10302  Not an Ejectment                Possession
# 67715              10011  Not an Ejectment                Possession
#
#        Latitude  Longitude  Community_Board  Council_District  Census_Tract  \
# 25          NaN        NaN              NaN               NaN           NaN
# 29          NaN        NaN              NaN               NaN           NaN
# 35          NaN        NaN              NaN               NaN           NaN
# 71          NaN        NaN              NaN               NaN           NaN
# 74          NaN        NaN              NaN               NaN           NaN
# ...         ...        ...              ...               ...           ...
# 67676       NaN        NaN              NaN               NaN           NaN
# 67700       NaN        NaN              NaN               NaN           NaN
# 67705       NaN        NaN              NaN               NaN           NaN
# 67713       NaN        NaN              NaN               NaN           NaN
# 67715       NaN        NaN              NaN               NaN           NaN
#
#        BIN  BBL  NTA
# 25     NaN  NaN  NaN
# 29     NaN  NaN  NaN
# 35     NaN  NaN  NaN
# 71     NaN  NaN  NaN
# 74     NaN  NaN  NaN
# ...    ...  ...  ...
# 67676  NaN  NaN  NaN
# 67700  NaN  NaN  NaN
# 67705  NaN  NaN  NaN
# 67713  NaN  NaN  NaN
# 67715  NaN  NaN  NaN
#
# [6444 rows x 20 columns]

# %% [markdown]
# ## Wanted to check if there were duplicates in dataset
#
# I found that there were 544 duplicated rows the same exact info accross all columns. Usually they are right after the other but in some cases seperated in but alot of rows in between

# %%
#this will give me the number of duplicates of rows with the same data all the way across the columns
#I wrapped the evictions_df_subset.duplicated().value_counts() in pd.DataFrame() for better readability
pd.DataFrame(evictions_df_subset.duplicated().value_counts())
# Out:
#            0
# False  67184
# True     544

# %%
#drop the duplicates from the dataset
clean_subset = evictions_df_subset.drop_duplicates()
clean_subset
# Out:
#       Court_Index_Number  Docket_Number_         Eviction_Address  \
# 0               50365/19          352435     319 WEST 94TH STREET
# 1             B068159/16          379048         2332 CRESTON AVE
# 2               59891/16          320691   2670 BAINBRIDGE AVENUE
# 3               75708/18          115775          18-24 25TH ROAD
# 4              900940/18           86395  3005 EASTCHESTER  RO AD
# ...                  ...             ...                      ...
# 67723         R 50452/17           68450     182 ARLINGTON AVENUE
# 67724          N66489/17           81749   600 WEST 136TH STREE T
# 67725         60675/17-1          208636         115 LINCOLN ROAD
# 67726          B42335/17           83318  1131-1133 OGDEN AVEN UE
# 67727           20290/16           59510             5 FLEET WALK
#
#       Eviction_Apartment_Number Executed_Date Marshal_First_Name  \
# 0                          C103    2019-03-25             Thomas
# 1                            41    2017-04-25            Richard
# 2                            2F    2017-02-21               John
# 3                             1    2019-04-23             Maxine
# 4                    STOREFRONT    2018-11-08             Justin
# ...                         ...           ...                ...
# 67723                       NaN    2017-03-29             Steven
# 67724                        6F    2017-09-27             Ileana
# 67725                        3N    2020-01-09            Richard
# 67726                       12A    2017-12-13             Ileana
# 67727                       08E    2017-08-02             Justin
#
#       Marshal_Last_Name Residential/Commercial        BOROUGH  \
# 0                   Bia            Residential      MANHATTAN
# 1                 McCoy            Residential          BRONX
# 2            Villanueva            Residential          BRONX
# 3              Chevlowe            Residential         QUEENS
# 4              Grossman             Commercial          BRONX
# ...                 ...                    ...            ...
# 67723            Powell            Residential  STATEN ISLAND
# 67724            Rivera            Residential      MANHATTAN
# 67725           Capuano            Residential       BROOKLYN
# 67726            Rivera            Residential          BRONX
# 67727          Grossman            Residential       BROOKLYN
#
#        Eviction_Postcode         Ejectment Eviction/Legal_Possession  \
# 0                  10025  Not an Ejectment                Possession
# 1                  10468  Not an Ejectment                Possession
# 2                  10458  Not an Ejectment                Possession
# 3                  11102  Not an Ejectment                Possession
# 4                  10469  Not an Ejectment                Possession
# ...                  ...               ...                       ...
# 67723              10303  Not an Ejectment                Possession
# 67724              10031  Not an Ejectment                Possession
# 67725              11225  Not an Ejectment                Possession
# 67726              10452  Not an Ejectment                Possession
# 67727              11201  Not an Ejectment                Possession
#
#         Latitude  Longitude  Community_Board  Council_District  Census_Tract  \
# 0      40.794205 -73.974734              7.0               6.0         183.0
# 1      40.858643 -73.900402              5.0              14.0       23703.0
# 2      40.865470 -73.891472              7.0              15.0       40502.0
# 3      40.774861 -73.926140              1.0              22.0          91.0
# 4      40.869607 -73.842766             12.0              12.0         358.0
# ...          ...        ...              ...               ...           ...
# 67723  40.635485 -74.167531              1.0              49.0         323.0
# 67724  40.820935 -73.954996              9.0               7.0       22301.0
# 67725  40.661077 -73.958799              9.0              40.0       79801.0
# 67726  40.836286 -73.927496              4.0              16.0         199.0
# 67727  40.695529 -73.981230              2.0              35.0          15.0
#
#              BIN           BBL  \
# 0      1034178.0  1.012530e+09
# 1      2013777.0  2.031640e+09
# 2      2016620.0  2.032870e+09
# 3      4019956.0  4.008870e+09
# 4      2061802.0  2.047620e+09
# ...          ...           ...
# 67723  5028488.0  5.012670e+09
# 67724  1059959.0  1.020020e+09
# 67725  3379187.0  3.013270e+09
# 67726  2088158.0  2.025260e+09
# 67727  3257046.0  3.020500e+09
#
#                                                      NTA
# 0                                        Upper West Side
# 1                                          Fordham South
# 2                             Bedford Park-Fordham North
# 3                                            Old Astoria
# 4                        Eastchester-Edenwald-Baychester
# ...                                                  ...
# 67723  Mariner's Harbor-Arlington-Port Ivory-Granitev...
# 67724                                     Manhattanville
# 67725                  Prospect Lefferts Gardens-Wingate
# 67726                                         Highbridge
# 67727   DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill
#
# [67184 rows x 20 columns]

# %%
pd.DataFrame(clean_subset.duplicated().value_counts())
# Out:
#            0
# False  67184

# %%
pd.DataFrame(evictions_df_subset['BOROUGH'].value_counts()).plot(kind='bar', figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
evictions_df_subset.hist(bins=60, figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'Docket_Number_'}>,
#         <AxesSubplot:title={'center':'Executed_Date'}>,
#         <AxesSubplot:title={'center':'Eviction_Postcode'}>],
#        [<AxesSubplot:title={'center':'Latitude'}>,
#         <AxesSubplot:title={'center':'Longitude'}>,
#         <AxesSubplot:title={'center':'Community_Board'}>],
#        [<AxesSubplot:title={'center':'Council_District'}>,
#         <AxesSubplot:title={'center':'Census_Tract'}>,
#         <AxesSubplot:title={'center':'BIN'}>],
#        [<AxesSubplot:title={'center':'BBL'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
evictions_df_subset[['Latitude', 'Longitude']].plot(kind='scatter', x = 'Latitude', y='Longitude', figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Latitude', ylabel='Longitude'>

# %%
#I wanted to double check that the duplicates found were indeed duplicates and where they were indexed at
#evictions_df_subset.loc[(evictions_df_subset['Docket_Number_']== 359312)]

# %% [markdown]
# ## My review of the nulls led to bringing back the deleted rows
#
# Intially I removed some rows (Community_Board, Council_District, Census_Tract, BIN, BBL, NTA) because I didnt think that I would need them in analysising this data set, but when I looked at the nulls in the Latitude and 	Longitude, it didn't make sense why those are null only with the rows I had left, so I add the rest of the deleted rows back and I noticed that those rows were null too.

# %%
#lets find what BIN and BBL are null but the other rows aren't 
#pd.set_option("display.max_rows", None)
clean_subset.loc[(clean_subset['BIN'].isna())
                        & (clean_subset['BBL'].isna())
                        & (clean_subset['Latitude'].notna())].head()
# Out:
#      Court_Index_Number  Docket_Number_  \
# 405            74214/18          116098
# 798           058542/18           89327
# 1303          62387/17A           67187
# 1896           70417/19          100869
# 2651         B901904/18           94609
#
#                                        Eviction_Address  \
# 405                                70-21C AUSTIN STREET
# 798   10-27 WYCKOFF AVENUE A/K/A 10-29 WYCKOFF AVENU...
# 1303                                224-27A 67TH AVENUE
# 1896                                  229 CHERRY STREET
# 2651        1872 CARTER AVENUE A KA 1877 WEBSTER AVENUE
#
#      Eviction_Apartment_Number Executed_Date Marshal_First_Name  \
# 405                        NaN    2019-07-25             Maxine
# 798                        NaN    2018-11-26              Henry
# 1303                      319A    2018-11-30             Justin
# 1896                       11H    2020-01-07              Henry
# 2651                  UNIT 3BM    2019-03-05             Ileana
#
#      Marshal_Last_Name Residential/Commercial    BOROUGH  Eviction_Postcode  \
# 405           Chevlowe             Commercial     QUEENS              11375
# 798              Daley             Commercial     QUEENS              11385
# 1303          Grossman            Residential     QUEENS              11364
# 1896             Daley            Residential  MANHATTAN              10002
# 2651            Rivera             Commercial      BRONX              10457
#
#              Ejectment Eviction/Legal_Possession   Latitude  Longitude  \
# 405   Not an Ejectment                Possession  40.720724 -73.846303
# 798   Not an Ejectment                Possession  40.695469 -73.903833
# 1303  Not an Ejectment                Possession  40.746257 -73.751252
# 1896  Not an Ejectment                Possession  40.711071 -73.990827
# 2651  Not an Ejectment                Possession  40.847268 -73.901922
#
#       Community_Board  Council_District  Census_Tract  BIN  BBL  \
# 405               6.0              29.0         711.0  NaN  NaN
# 798               5.0              34.0         555.0  NaN  NaN
# 1303             11.0              23.0        1377.0  NaN  NaN
# 1896              3.0               1.0           6.0  NaN  NaN
# 2651              5.0              15.0         231.0  NaN  NaN
#
#                   NTA
# 405      Forest Hills
# 798         Ridgewood
# 1303  Oakland Gardens
# 1896  Lower East Side
# 2651       Mount Hope

# %%
clean_subset.loc[(clean_subset['BIN'].isna())
                        & (clean_subset['BBL'].isna())
                        & (clean_subset['Latitude'].isna())].head()
# Out:
#    Court_Index_Number  Docket_Number_                        Eviction_Address  \
# 25           52516/18           33234  39-19 103RD STREET OFFICE FOR TAX PREP
# 29         50655/17-2            7316    62-08 MYRTLE AVENUE  FRONT APARTMENT
# 35           63238/17          152860        1094 LENOX ROAD (1ST.FLR ENTIRE)
# 71           53925/16           79746           359 FORT   WASHINGTO N AVENUE
# 74           98056/16            4957    445 AMBOY STREET APT.  RM 1 BASEMENT
#
#    Eviction_Apartment_Number Executed_Date Marshal_First_Name  \
# 25                       NaN    2018-09-12              Bruce
# 29                       NaN    2017-07-05             George
# 35                       NaN    2017-10-31             Ronald
# 71                        3C    2018-09-11             Justin
# 74                 BSMT RM.1    2017-04-20             Robert
#
#    Marshal_Last_Name Residential/Commercial    BOROUGH  Eviction_Postcode  \
# 25              Kemp             Commercial     QUEENS              11368
# 29       Essock, Jr.            Residential     QUEENS              11385
# 35            Pazant            Residential   BROOKLYN              11212
# 71          Grossman            Residential  MANHATTAN              10033
# 74          Renzulli            Residential   BROOKLYN              11212
#
#            Ejectment Eviction/Legal_Possession  Latitude  Longitude  \
# 25  Not an Ejectment                Possession       NaN        NaN
# 29  Not an Ejectment                Possession       NaN        NaN
# 35  Not an Ejectment                Possession       NaN        NaN
# 71  Not an Ejectment                Possession       NaN        NaN
# 74  Not an Ejectment                Possession       NaN        NaN
#
#     Community_Board  Council_District  Census_Tract  BIN  BBL  NTA
# 25              NaN               NaN           NaN  NaN  NaN  NaN
# 29              NaN               NaN           NaN  NaN  NaN  NaN
# 35              NaN               NaN           NaN  NaN  NaN  NaN
# 71              NaN               NaN           NaN  NaN  NaN  NaN
# 74              NaN               NaN           NaN  NaN  NaN  NaN

# %%
final_clean_subset = clean_subset[['Eviction_Address',
         'Executed_Date', 'Residential/Commercial', 'BOROUGH',
       'Eviction_Postcode', 'Ejectment', 'Eviction/Legal_Possession',
       'Latitude', 'Longitude', 'Community_Board', 'Council_District','NTA']]

final_clean_subset.rename(columns={'Residential/Commercial':'Property_type', 'BOROUGH':'Borough'})
#clean_subset
# Out:
#               Eviction_Address Executed_Date Property_type        Borough  \
# 0         319 WEST 94TH STREET    2019-03-25   Residential      MANHATTAN
# 1             2332 CRESTON AVE    2017-04-25   Residential          BRONX
# 2       2670 BAINBRIDGE AVENUE    2017-02-21   Residential          BRONX
# 3              18-24 25TH ROAD    2019-04-23   Residential         QUEENS
# 4      3005 EASTCHESTER  RO AD    2018-11-08    Commercial          BRONX
# ...                        ...           ...           ...            ...
# 67723     182 ARLINGTON AVENUE    2017-03-29   Residential  STATEN ISLAND
# 67724   600 WEST 136TH STREE T    2017-09-27   Residential      MANHATTAN
# 67725         115 LINCOLN ROAD    2020-01-09   Residential       BROOKLYN
# 67726  1131-1133 OGDEN AVEN UE    2017-12-13   Residential          BRONX
# 67727             5 FLEET WALK    2017-08-02   Residential       BROOKLYN
#
#        Eviction_Postcode         Ejectment Eviction/Legal_Possession  \
# 0                  10025  Not an Ejectment                Possession
# 1                  10468  Not an Ejectment                Possession
# 2                  10458  Not an Ejectment                Possession
# 3                  11102  Not an Ejectment                Possession
# 4                  10469  Not an Ejectment                Possession
# ...                  ...               ...                       ...
# 67723              10303  Not an Ejectment                Possession
# 67724              10031  Not an Ejectment                Possession
# 67725              11225  Not an Ejectment                Possession
# 67726              10452  Not an Ejectment                Possession
# 67727              11201  Not an Ejectment                Possession
#
#         Latitude  Longitude  Community_Board  Council_District  \
# 0      40.794205 -73.974734              7.0               6.0
# 1      40.858643 -73.900402              5.0              14.0
# 2      40.865470 -73.891472              7.0              15.0
# 3      40.774861 -73.926140              1.0              22.0
# 4      40.869607 -73.842766             12.0              12.0
# ...          ...        ...              ...               ...
# 67723  40.635485 -74.167531              1.0              49.0
# 67724  40.820935 -73.954996              9.0               7.0
# 67725  40.661077 -73.958799              9.0              40.0
# 67726  40.836286 -73.927496              4.0              16.0
# 67727  40.695529 -73.981230              2.0              35.0
#
#                                                      NTA
# 0                                        Upper West Side
# 1                                          Fordham South
# 2                             Bedford Park-Fordham North
# 3                                            Old Astoria
# 4                        Eastchester-Edenwald-Baychester
# ...                                                  ...
# 67723  Mariner's Harbor-Arlington-Port Ivory-Granitev...
# 67724                                     Manhattanville
# 67725                  Prospect Lefferts Gardens-Wingate
# 67726                                         Highbridge
# 67727   DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill
#
# [67184 rows x 12 columns]

# %%
clean_subset
# Out:
#       Court_Index_Number  Docket_Number_         Eviction_Address  \
# 0               50365/19          352435     319 WEST 94TH STREET
# 1             B068159/16          379048         2332 CRESTON AVE
# 2               59891/16          320691   2670 BAINBRIDGE AVENUE
# 3               75708/18          115775          18-24 25TH ROAD
# 4              900940/18           86395  3005 EASTCHESTER  RO AD
# ...                  ...             ...                      ...
# 67723         R 50452/17           68450     182 ARLINGTON AVENUE
# 67724          N66489/17           81749   600 WEST 136TH STREE T
# 67725         60675/17-1          208636         115 LINCOLN ROAD
# 67726          B42335/17           83318  1131-1133 OGDEN AVEN UE
# 67727           20290/16           59510             5 FLEET WALK
#
#       Eviction_Apartment_Number Executed_Date Marshal_First_Name  \
# 0                          C103    2019-03-25             Thomas
# 1                            41    2017-04-25            Richard
# 2                            2F    2017-02-21               John
# 3                             1    2019-04-23             Maxine
# 4                    STOREFRONT    2018-11-08             Justin
# ...                         ...           ...                ...
# 67723                       NaN    2017-03-29             Steven
# 67724                        6F    2017-09-27             Ileana
# 67725                        3N    2020-01-09            Richard
# 67726                       12A    2017-12-13             Ileana
# 67727                       08E    2017-08-02             Justin
#
#       Marshal_Last_Name Residential/Commercial        BOROUGH  \
# 0                   Bia            Residential      MANHATTAN
# 1                 McCoy            Residential          BRONX
# 2            Villanueva            Residential          BRONX
# 3              Chevlowe            Residential         QUEENS
# 4              Grossman             Commercial          BRONX
# ...                 ...                    ...            ...
# 67723            Powell            Residential  STATEN ISLAND
# 67724            Rivera            Residential      MANHATTAN
# 67725           Capuano            Residential       BROOKLYN
# 67726            Rivera            Residential          BRONX
# 67727          Grossman            Residential       BROOKLYN
#
#        Eviction_Postcode         Ejectment Eviction/Legal_Possession  \
# 0                  10025  Not an Ejectment                Possession
# 1                  10468  Not an Ejectment                Possession
# 2                  10458  Not an Ejectment                Possession
# 3                  11102  Not an Ejectment                Possession
# 4                  10469  Not an Ejectment                Possession
# ...                  ...               ...                       ...
# 67723              10303  Not an Ejectment                Possession
# 67724              10031  Not an Ejectment                Possession
# 67725              11225  Not an Ejectment                Possession
# 67726              10452  Not an Ejectment                Possession
# 67727              11201  Not an Ejectment                Possession
#
#         Latitude  Longitude  Community_Board  Council_District  Census_Tract  \
# 0      40.794205 -73.974734              7.0               6.0         183.0
# 1      40.858643 -73.900402              5.0              14.0       23703.0
# 2      40.865470 -73.891472              7.0              15.0       40502.0
# 3      40.774861 -73.926140              1.0              22.0          91.0
# 4      40.869607 -73.842766             12.0              12.0         358.0
# ...          ...        ...              ...               ...           ...
# 67723  40.635485 -74.167531              1.0              49.0         323.0
# 67724  40.820935 -73.954996              9.0               7.0       22301.0
# 67725  40.661077 -73.958799              9.0              40.0       79801.0
# 67726  40.836286 -73.927496              4.0              16.0         199.0
# 67727  40.695529 -73.981230              2.0              35.0          15.0
#
#              BIN           BBL  \
# 0      1034178.0  1.012530e+09
# 1      2013777.0  2.031640e+09
# 2      2016620.0  2.032870e+09
# 3      4019956.0  4.008870e+09
# 4      2061802.0  2.047620e+09
# ...          ...           ...
# 67723  5028488.0  5.012670e+09
# 67724  1059959.0  1.020020e+09
# 67725  3379187.0  3.013270e+09
# 67726  2088158.0  2.025260e+09
# 67727  3257046.0  3.020500e+09
#
#                                                      NTA
# 0                                        Upper West Side
# 1                                          Fordham South
# 2                             Bedford Park-Fordham North
# 3                                            Old Astoria
# 4                        Eastchester-Edenwald-Baychester
# ...                                                  ...
# 67723  Mariner's Harbor-Arlington-Port Ivory-Granitev...
# 67724                                     Manhattanville
# 67725                  Prospect Lefferts Gardens-Wingate
# 67726                                         Highbridge
# 67727   DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill
#
# [67184 rows x 20 columns]

# %%
final_clean_subset[clean_subset['Ejectment'] == 'Ejectment']
# Out:
#                                         Eviction_Address Executed_Date  \
# 3754                67 35TH ST.(BLDG#5) (WEST C-SECTION)    2017-03-08
# 4450            230 WEST 111TH ST. - BUILDING 3 & APT 3C    2018-03-28
# 5935                                 111-43 139TH STREET    2018-04-06
# 7855                                124 SUNSET BOULEVARD    2018-12-10
# 8947                                  2743 FENTON AVENUE    2019-08-14
# 10949                          90-02 QUEENS   BOULE VARD    2021-08-27
# 11930                              922 EAST 221ST STREET    2017-09-20
# 12594                              629 EAST 229TH STREET    2017-01-03
# 14422                                     1350 MANOR AVE    2019-12-12
# 19687                               2943 PEARSALL AVENUE    2018-03-06
# 20371                                  64 HANCOCK STREET    2019-04-05
# 23244                                  3953 PAULDING AVE    2018-07-02
# 23541                                 1490 BRYANT AVENUE    2017-12-13
# 23614                                1319 NEEDHAM AVENUE    2017-03-23
# 24789                             170 WEST 233RD STREE T    2017-09-14
# 25272                                  241-21 CANEY ROAD    2017-09-06
# 25562                            786 9TH AVENUE - APT 1R    2019-01-07
# 25829                                  34-13 99TH STREET    2020-02-18
# 27240                                 2672 BRIGGS AVENUE    2017-05-02
# 27907  249 EAST 48TH STREET AKA 909 SECOND AVENUE THE...    2018-10-23
# 27930                                  207 AUTUMN AVENUE    2021-09-01
# 28470                             232-234 W 149TH STREET    2019-09-04
# 28598        831 PENFIELD STREET WALK IN APT, FRONT ROOM    2019-07-09
# 34185                             3278 KINGSLAND AVENU E    2017-01-03
# 35329                                 1517 MORRIS AVENUE    2018-10-29
# 39175                                370 NEW YORK AVENUE    2017-07-25
# 40371                               333 BEACH 101 STREET    2022-02-24
# 40800                                 1704 PITMAN AVENUE    2017-06-12
# 41647                                2243 CROPSEY AVENUE    2018-04-06
# 42275                     103 VAN COURTLANDT AVENUE WEST    2017-01-09
# 42405                                  4040 PRATT AVENUE    2019-07-02
# 47823                                164 ST. JOHNS PLACE    2019-10-08
# 48820                              930 EAST 227TH STREET    2017-12-13
# 48835                                401 EAST 8TH STREET    2020-02-21
# 49100                  1490 BRYANT AVE 3RD FL RIGHT SIDE    2017-11-22
# 49407                                 631 EAST 226TH ST.    2017-07-06
# 49575                                 2393 WALTON AVENUE    2020-01-23
# 50454                                 738 CHESTER STREET    2019-11-18
# 53171                                647 JEFFERSON PLACE    2019-09-24
# 54949                   9203 FOSTER AVENUE  BACK BEDROOM    2017-12-11
# 55515                              521 WEST 185TH STREET    2018-04-24
# 56966                              280 EAST 161ST STREET    2019-05-29
# 58436                                 1490 BRYANT AVENUE    2017-02-17
# 58537                                 250-04 87TH AVENUE    2018-06-11
# 63560                                111-35 132ND STREET    2017-03-31
# 63883                                 1023 BRYANT AVENUE    2018-03-16
# 64435                                817 CHESTNUT AVENUE    2019-11-08
# 65937                                 1460 BRYANT AVENUE    2017-01-11
# 67564                                      2612 BROADWAY    2018-01-30
#
#       Residential/Commercial    BOROUGH  Eviction_Postcode  Ejectment  \
# 3754              Commercial   BROOKLYN              11232  Ejectment
# 4450             Residential  MANHATTAN              10026  Ejectment
# 5935             Residential     QUEENS              11434  Ejectment
# 7855             Residential      BRONX              10473  Ejectment
# 8947             Residential      BRONX              10469  Ejectment
# 10949            Residential     QUEENS              11373  Ejectment
# 11930            Residential      BRONX              10469  Ejectment
# 12594            Residential      BRONX              10466  Ejectment
# 14422            Residential      BRONX              10472  Ejectment
# 19687            Residential      BRONX              10469  Ejectment
# 20371            Residential   BROOKLYN              11216  Ejectment
# 23244            Residential      BRONX              10466  Ejectment
# 23541             Commercial      BRONX              10460  Ejectment
# 23614            Residential      BRONX              10469  Ejectment
# 24789             Commercial      BRONX              10463  Ejectment
# 25272            Residential     QUEENS              11422  Ejectment
# 25562            Residential  MANHATTAN              10019  Ejectment
# 25829            Residential     QUEENS              11368  Ejectment
# 27240            Residential      BRONX              10458  Ejectment
# 27907             Commercial  MANHATTAN              10017  Ejectment
# 27930            Residential   BROOKLYN              11208  Ejectment
# 28470            Residential  MANHATTAN              10039  Ejectment
# 28598            Residential      BRONX              10470  Ejectment
# 34185            Residential      BRONX              10469  Ejectment
# 35329            Residential      BRONX              10457  Ejectment
# 39175            Residential   BROOKLYN              11203  Ejectment
# 40371            Residential     QUEENS              11694  Ejectment
# 40800            Residential      BRONX              10466  Ejectment
# 41647            Residential   BROOKLYN              11214  Ejectment
# 42275            Residential      BRONX              10463  Ejectment
# 42405            Residential      BRONX              10466  Ejectment
# 47823            Residential   BROOKLYN              11201  Ejectment
# 48820            Residential      BRONX              10466  Ejectment
# 48835            Residential   BROOKLYN              11218  Ejectment
# 49100            Residential      BRONX              10460  Ejectment
# 49407            Residential      BRONX              10466  Ejectment
# 49575            Residential      BRONX              10468  Ejectment
# 50454             Commercial   BROOKLYN              11236  Ejectment
# 53171            Residential      BRONX              10456  Ejectment
# 54949            Residential   BROOKLYN              11236  Ejectment
# 55515            Residential  MANHATTAN              10033  Ejectment
# 56966            Residential      BRONX              10451  Ejectment
# 58436            Residential      BRONX              10460  Ejectment
# 58537            Residential     QUEENS              11426  Ejectment
# 63560            Residential     QUEENS              11420  Ejectment
# 63883            Residential      BRONX              10454  Ejectment
# 64435            Residential      BRONX              10467  Ejectment
# 65937            Residential      BRONX              10460  Ejectment
# 67564            Residential  MANHATTAN              10025  Ejectment
#
#       Eviction/Legal_Possession   Latitude  Longitude  Community_Board  \
# 3754                 Possession        NaN        NaN              NaN
# 4450                 Possession        NaN        NaN              NaN
# 5935                 Possession  40.684809 -73.805029             12.0
# 7855                 Possession  40.805928 -73.854111              9.0
# 8947                 Possession  40.865896 -73.844355             11.0
# 10949                  Eviction  40.734068 -73.872403              4.0
# 11930                Possession  40.882892 -73.855486             12.0
# 12594                Possession  40.891396 -73.861276             12.0
# 14422                Possession  40.833016 -73.877331              9.0
# 19687                Possession  40.868425 -73.851866             11.0
# 20371                  Eviction  40.682215 -73.952732              3.0
# 23244                Possession  40.884595 -73.852260             12.0
# 23541                Possession  40.832518 -73.887461              3.0
# 23614                Possession  40.878035 -73.852275             12.0
# 24789                  Eviction  40.880298 -73.902738              8.0
# 25272                  Eviction  40.661490 -73.740085             13.0
# 25562                Possession  40.764937 -73.987874              4.0
# 25829                Possession  40.755015 -73.869090              3.0
# 27240                Possession  40.865819 -73.892093              7.0
# 27907                Possession  40.754111 -73.970565              6.0
# 27930                  Eviction  40.685242 -73.870532              5.0
# 28470                Possession  40.824655 -73.938359             10.0
# 28598                Possession        NaN        NaN              NaN
# 34185                Possession  40.875117 -73.843328             12.0
# 35329                Possession  40.841658 -73.909513              4.0
# 39175                Possession  40.666905 -73.948006              9.0
# 40371                Possession  40.585499 -73.822960             14.0
# 40800                Possession  40.894976 -73.852848             12.0
# 41647                Possession  40.596452 -73.997659             11.0
# 42275                Possession        NaN        NaN              NaN
# 42405                Possession  40.891868 -73.833802             12.0
# 47823                Possession  40.676746 -73.974886              6.0
# 48820                Possession  40.887047 -73.852891             12.0
# 48835                Possession  40.640242 -73.971005             12.0
# 49100                Possession        NaN        NaN              NaN
# 49407                Possession  40.889260 -73.862395             12.0
# 49575                Possession  40.860960 -73.901219              5.0
# 50454                Possession  40.653334 -73.907534             16.0
# 53171                  Eviction  40.833273 -73.899576              3.0
# 54949                  Eviction        NaN        NaN              NaN
# 55515                Possession  40.850823 -73.929898             12.0
# 56966                Possession  40.825375 -73.917846              4.0
# 58436                Possession  40.832518 -73.887461              3.0
# 58537                Possession  40.730467 -73.715742             13.0
# 63560                Possession  40.682727 -73.810234             10.0
# 63883                Possession  40.824052 -73.888627              2.0
# 64435                Possession        NaN        NaN              NaN
# 65937                Possession  40.831876 -73.887845              3.0
# 67564                Possession  40.796347 -73.970536              7.0
#
#        Council_District                                                NTA
# 3754                NaN                                                NaN
# 4450                NaN                                                NaN
# 5935               28.0                                      South Jamaica
# 7855               18.0    Soundview-Castle Hill-Clason Point-Harding Park
# 8947               13.0                            Allerton-Pelham Gardens
# 10949              25.0                                           Elmhurst
# 11930              12.0                           Williamsbridge-Olinville
# 12594              12.0                           Williamsbridge-Olinville
# 14422              18.0                             West Farms-Bronx River
# 19687              12.0                            Allerton-Pelham Gardens
# 20371              36.0                                            Bedford
# 23244              12.0                           Williamsbridge-Olinville
# 23541              17.0                                  Crotona Park East
# 23614              12.0                           Williamsbridge-Olinville
# 24789              11.0                         Spuyten Duyvil-Kingsbridge
# 25272              31.0                                           Rosedale
# 25562               3.0                                            Clinton
# 25829              21.0                                       North Corona
# 27240              15.0                         Bedford Park-Fordham North
# 27907               4.0                            Turtle Bay-East Midtown
# 27930              37.0                            Cypress Hills-City Line
# 28470               9.0                  Central Harlem North-Polo Grounds
# 28598               NaN                                                NaN
# 34185              12.0                    Eastchester-Edenwald-Baychester
# 35329              16.0                   East Concourse-Concourse Village
# 39175              35.0                                Crown Heights South
# 40371              32.0  Breezy Point-Belle Harbor-Rockaway Park-Broad ...
# 40800              12.0                                 Woodlawn-Wakefield
# 41647              47.0                                   Bensonhurst West
# 42275               NaN                                                NaN
# 42405              12.0                    Eastchester-Edenwald-Baychester
# 47823              39.0                                 Park Slope-Gowanus
# 48820              12.0                           Williamsbridge-Olinville
# 48835              40.0                           Kensington-Ocean Parkway
# 49100               NaN                                                NaN
# 49407              12.0                           Williamsbridge-Olinville
# 49575              14.0                                      Fordham South
# 50454              42.0                                        Brownsville
# 53171              16.0                                 Morrisania-Melrose
# 54949               NaN                                                NaN
# 55515              10.0                           Washington Heights North
# 56966              16.0                   East Concourse-Concourse Village
# 58436              17.0                                  Crotona Park East
# 58537              23.0                                          Bellerose
# 63560              28.0                                   South Ozone Park
# 63883              17.0                                        Hunts Point
# 64435               NaN                                                NaN
# 65937              17.0                                  Crotona Park East
# 67564               7.0                                    Upper West Side

# %%
final_clean_subset.isna().sum()
# Out:
# Eviction_Address                0
# Executed_Date                   0
# Residential/Commercial          0
# BOROUGH                         0
# Eviction_Postcode               0
# Ejectment                       0
# Eviction/Legal_Possession       0
# Latitude                     6421
# Longitude                    6421
# Community_Board              6421
# Council_District             6421
# NTA                          6421
# dtype: int64

# %%
mask =(final_clean_subset['Latitude'].isna())

# %%
final_clean_subset.loc[mask]= final_clean_subset.loc[mask].fillna('Not Provided')
# Out:
# /var/folders/vt/z4wqy62s42j80vnmm1nvtf6h0000gp/T/ipykernel_25618/607291491.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_clean_subset.loc[mask]= final_clean_subset.loc[mask].fillna('Not Provided')

# %%
final_clean_subset[final_clean_subset['Latitude']== 'Not Provided']
# Out:
#                                         Eviction_Address Executed_Date  \
# 25                39-19 103RD STREET OFFICE FOR TAX PREP    2018-09-12
# 29                  62-08 MYRTLE AVENUE  FRONT APARTMENT    2017-07-05
# 35                      1094 LENOX ROAD (1ST.FLR ENTIRE)    2017-10-31
# 71                         359 FORT   WASHINGTO N AVENUE    2018-09-11
# 74                  445 AMBOY STREET APT.  RM 1 BASEMENT    2017-04-20
# ...                                                  ...           ...
# 67676                   142-06 185TH STREET ENTIRE HOUSE    2019-11-06
# 67700    11 VARICK STREET (A/ K/A 16 NORTH MOORE STREET)    2020-01-30
# 67705                     431 HERZL ST - APT 1F (1ST FL)    2018-11-15
# 67713                           1955 RICHMOND   TERR ACE    2020-01-17
# 67715  153 EIGHTH AVENUE - NORTHERNMOST STORE & PORTI...    2019-11-07
#
#       Residential/Commercial        BOROUGH  Eviction_Postcode  \
# 25                Commercial         QUEENS              11368
# 29               Residential         QUEENS              11385
# 35               Residential       BROOKLYN              11212
# 71               Residential      MANHATTAN              10033
# 74               Residential       BROOKLYN              11212
# ...                      ...            ...                ...
# 67676            Residential         QUEENS              11413
# 67700            Residential      MANHATTAN              10013
# 67705            Residential       BROOKLYN              11212
# 67713            Residential  STATEN ISLAND              10302
# 67715             Commercial      MANHATTAN              10011
#
#               Ejectment Eviction/Legal_Possession      Latitude     Longitude  \
# 25     Not an Ejectment                Possession  Not Provided  Not Provided
# 29     Not an Ejectment                Possession  Not Provided  Not Provided
# 35     Not an Ejectment                Possession  Not Provided  Not Provided
# 71     Not an Ejectment                Possession  Not Provided  Not Provided
# 74     Not an Ejectment                Possession  Not Provided  Not Provided
# ...                 ...                       ...           ...           ...
# 67676  Not an Ejectment                Possession  Not Provided  Not Provided
# 67700  Not an Ejectment                Possession  Not Provided  Not Provided
# 67705  Not an Ejectment                Possession  Not Provided  Not Provided
# 67713  Not an Ejectment                Possession  Not Provided  Not Provided
# 67715  Not an Ejectment                Possession  Not Provided  Not Provided
#
#       Community_Board Council_District           NTA
# 25       Not Provided     Not Provided  Not Provided
# 29       Not Provided     Not Provided  Not Provided
# 35       Not Provided     Not Provided  Not Provided
# 71       Not Provided     Not Provided  Not Provided
# 74       Not Provided     Not Provided  Not Provided
# ...               ...              ...           ...
# 67676    Not Provided     Not Provided  Not Provided
# 67700    Not Provided     Not Provided  Not Provided
# 67705    Not Provided     Not Provided  Not Provided
# 67713    Not Provided     Not Provided  Not Provided
# 67715    Not Provided     Not Provided  Not Provided
#
# [6421 rows x 12 columns]

# %%
final_clean_subset.isna().sum()
# Out:
# Eviction_Address             0
# Executed_Date                0
# Residential/Commercial       0
# BOROUGH                      0
# Eviction_Postcode            0
# Ejectment                    0
# Eviction/Legal_Possession    0
# Latitude                     0
# Longitude                    0
# Community_Board              0
# Council_District             0
# NTA                          0
# dtype: int64

# %%
final_clean_subset = final_clean_subset.rename(
    columns = {'Property_type':'Property_Type', 'BOROUGH':'Borough', 'NTA':'Neighborhood_Tabulation_Area'})

# %%
final_clean_subset
# Out:
#               Eviction_Address Executed_Date Property_Type        Borough  \
# 0         319 WEST 94TH STREET    2019-03-25   Residential      MANHATTAN
# 1             2332 CRESTON AVE    2017-04-25   Residential          BRONX
# 2       2670 BAINBRIDGE AVENUE    2017-02-21   Residential          BRONX
# 3              18-24 25TH ROAD    2019-04-23   Residential         QUEENS
# 4      3005 EASTCHESTER  RO AD    2018-11-08    Commercial          BRONX
# ...                        ...           ...           ...            ...
# 67723     182 ARLINGTON AVENUE    2017-03-29   Residential  STATEN ISLAND
# 67724   600 WEST 136TH STREE T    2017-09-27   Residential      MANHATTAN
# 67725         115 LINCOLN ROAD    2020-01-09   Residential       BROOKLYN
# 67726  1131-1133 OGDEN AVEN UE    2017-12-13   Residential          BRONX
# 67727             5 FLEET WALK    2017-08-02   Residential       BROOKLYN
#
#        Eviction_Postcode         Ejectment Eviction/Legal_Possession  \
# 0                  10025  Not an Ejectment                Possession
# 1                  10468  Not an Ejectment                Possession
# 2                  10458  Not an Ejectment                Possession
# 3                  11102  Not an Ejectment                Possession
# 4                  10469  Not an Ejectment                Possession
# ...                  ...               ...                       ...
# 67723              10303  Not an Ejectment                Possession
# 67724              10031  Not an Ejectment                Possession
# 67725              11225  Not an Ejectment                Possession
# 67726              10452  Not an Ejectment                Possession
# 67727              11201  Not an Ejectment                Possession
#
#         Latitude  Longitude Community_Board Council_District  \
# 0      40.794205 -73.974734             7.0              6.0
# 1      40.858643 -73.900402             5.0             14.0
# 2       40.86547 -73.891472             7.0             15.0
# 3      40.774861  -73.92614             1.0             22.0
# 4      40.869607 -73.842766            12.0             12.0
# ...          ...        ...             ...              ...
# 67723  40.635485 -74.167531             1.0             49.0
# 67724  40.820935 -73.954996             9.0              7.0
# 67725  40.661077 -73.958799             9.0             40.0
# 67726  40.836286 -73.927496             4.0             16.0
# 67727  40.695529  -73.98123             2.0             35.0
#
#                             Neighborhood_Tabulation_Area
# 0                                        Upper West Side
# 1                                          Fordham South
# 2                             Bedford Park-Fordham North
# 3                                            Old Astoria
# 4                        Eastchester-Edenwald-Baychester
# ...                                                  ...
# 67723  Mariner's Harbor-Arlington-Port Ivory-Granitev...
# 67724                                     Manhattanville
# 67725                  Prospect Lefferts Gardens-Wingate
# 67726                                         Highbridge
# 67727   DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill
#
# [67184 rows x 12 columns]
