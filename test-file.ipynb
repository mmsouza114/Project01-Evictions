# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
df = pd.read_csv('transformed_evictions_df.csv')
df.info()

df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67184 entries, 0 to 67183
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Docket_Number_                67184 non-null  int64
#  1   Eviction_Address              67184 non-null  object
#  2   Executed_Date                 67184 non-null  object
#  3   Property_Type                 67184 non-null  object
#  4   Borough                       67184 non-null  object
#  5   Eviction_Postcode             67184 non-null  int64
#  6   Ejectment                     67184 non-null  object
#  7   Eviction/Legal_Possession     67184 non-null  object
#  8   Latitude                      60763 non-null  float64
#  9   Longitude                     60763 non-null  float64
#  10  Neighborhood_Tabulation_Area  60763 non-null  object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 5.6+ MB
# ...

# %%
#convert date executed type object into datetime
df['Executed_Date']= pd.to_datetime(df['Executed_Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67184 entries, 0 to 67183
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Docket_Number_                67184 non-null  int64
#  1   Eviction_Address              67184 non-null  object
#  2   Executed_Date                 67184 non-null  datetime64[ns]
#  3   Property_Type                 67184 non-null  object
#  4   Borough                       67184 non-null  object
#  5   Eviction_Postcode             67184 non-null  int64
#  6   Ejectment                     67184 non-null  object
#  7   Eviction/Legal_Possession     67184 non-null  object
#  8   Latitude                      60763 non-null  float64
#  9   Longitude                     60763 non-null  float64
#  10  Neighborhood_Tabulation_Area  60763 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(6)
# memory usage: 5.6+ MB

# %%
evict_2017 = df.loc[(df['Executed_Date'].dt.year == 2017)]
evict_2017
# Out:
#        Docket_Number_                         Eviction_Address Executed_Date  \
# 1              379048                         2332 CRESTON AVE    2017-04-25
# 2              320691                   2670 BAINBRIDGE AVENUE    2017-02-21
# 14              67648                        643 EAST 222ND ST    2017-10-30
# 16             468806  420 E. 61ST ST AKA O NE SUTTON PLACE N.    2017-06-01
# 18             377335                 2375 SOUTHERN  BOULEVARD    2017-09-19
# ...               ...                                      ...           ...
# 67176          199218                      90 EAST 18TH STREET    2017-02-23
# 67179           68450                     182 ARLINGTON AVENUE    2017-03-29
# 67180           81749                   600 WEST 136TH STREE T    2017-09-27
# 67182           83318                  1131-1133 OGDEN AVEN UE    2017-12-13
# 67183           59510                             5 FLEET WALK    2017-08-02
#
# ...

# %%
## top 5 postal codes with the most eviction count grouped by borough
top_evicts = df.groupby(['Borough', 'Neighborhood_Tabulation_Area']).Eviction_Postcode.value_counts().nlargest(5)
from sqlalchemy import create_enginepd.DataFrame(top_evicts)
# Out:
#   Input In [76]
#     from sqlalchemy import create_enginepd.DataFrame(top_evicts)
#                                           ^
# SyntaxError: invalid syntax

# %%
df= pd.read_csv('transformed_evictions_df.csv')
dataFrame = pd.DataFrame(df)
my_con = create_engine('mysql+pymysql://root:12345678@localhost/nycEvictions')

# %%
dataFrame.to_sql('cleanedEvictions',my_con)
# Out:
# 67184

# %%
df.duplicated().value_counts()
# Out:
# False    67182
# True         2
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#        Docket_Number_        Eviction_Address Executed_Date Property_Type  \
# 28599           18058  644 - EAST 78TH STREET    2017-04-10   Residential
# 41142           18059   644 -EAST 78TH STREET    2017-04-10   Residential
#
#         Borough  Eviction_Postcode         Ejectment  \
# 28599  BROOKLYN              11236  Not an Ejectment
# 41142  BROOKLYN              11236  Not an Ejectment
#
#       Eviction/Legal_Possession   Latitude  Longitude  \
# 28599                Possession        NaN        NaN
# 41142                Possession  40.636939  -73.91744
#
#       Neighborhood_Tabulation_Area
# 28599                          NaN
# 41142                     Canarsie

# %%
df[df.duplicated('Docket_Number_')]
# Out:
#        Docket_Number_                                   Eviction_Address  \
# 700             89754                                115-27 122ND STREET
# 977              2658                                323 EAST GUNHILL RD
# 996             18364              388 CHRISTOPHER AVEN UE  ENTIRE HOUSE
# 1664            91728                                 1064 CAULDWELL AVE
# 1704            97010                                  1469 PRESIDENT ST
# ...               ...                                                ...
# 67169           99309                           1955 RICHMOND   TERR ACE
# 67171           12034  153 EIGHTH AVENUE - NORTHERNMOST STORE & PORTI...
# 67172            2467                                 5212 GLENWOOD ROAD
# 67175           75742                                 1750 EAST 172ND ST
# 67180           81749                             600 WEST 136TH STREE T
#
#       Executed_Date Property_Type        Borough  Eviction_Postcode  \
# ...

# %%
df.shape
# Out:
# (67184, 11)

# %%
df[df.duplicated(keep=False)]
# Out:
#        Docket_Number_        Eviction_Address Executed_Date Property_Type  \
# 7519            18058  644 - EAST 78TH STREET    2017-04-10   Residential
# 10212           18059   644 -EAST 78TH STREET    2017-04-10   Residential
# 28599           18058  644 - EAST 78TH STREET    2017-04-10   Residential
# 41142           18059   644 -EAST 78TH STREET    2017-04-10   Residential
#
#         Borough  Eviction_Postcode         Ejectment  \
# 7519   BROOKLYN              11236  Not an Ejectment
# 10212  BROOKLYN              11236  Not an Ejectment
# 28599  BROOKLYN              11236  Not an Ejectment
# 41142  BROOKLYN              11236  Not an Ejectment
#
#       Eviction/Legal_Possession   Latitude  Longitude  \
# 7519                 Possession        NaN        NaN
# 10212                Possession  40.636939  -73.91744
# 28599                Possession        NaN        NaN
# 41142                Possession  40.636939  -73.91744
#
#       Neighborhood_Tabulation_Area
# ...

# %%
df[df.duplicated(keep=False)]
# Out:
#        Docket_Number_        Eviction_Address Executed_Date Property_Type  \
# 7519            18058  644 - EAST 78TH STREET    2017-04-10   Residential
# 10212           18059   644 -EAST 78TH STREET    2017-04-10   Residential
# 28599           18058  644 - EAST 78TH STREET    2017-04-10   Residential
# 41142           18059   644 -EAST 78TH STREET    2017-04-10   Residential
#
#         Borough  Eviction_Postcode         Ejectment  \
# 7519   BROOKLYN              11236  Not an Ejectment
# 10212  BROOKLYN              11236  Not an Ejectment
# 28599  BROOKLYN              11236  Not an Ejectment
# 41142  BROOKLYN              11236  Not an Ejectment
#
#       Eviction/Legal_Possession   Latitude  Longitude  \
# 7519                 Possession        NaN        NaN
# 10212                Possession  40.636939  -73.91744
# 28599                Possession        NaN        NaN
# 41142                Possession  40.636939  -73.91744
#
#       Neighborhood_Tabulation_Area
# ...

# %%
df = df.drop(labels=[7519,10212], axis=0)

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Docket_Number_, Eviction_Address, Executed_Date, Property_Type, Borough, Eviction_Postcode, Ejectment, Eviction/Legal_Possession, Latitude, Longitude, Neighborhood_Tabulation_Area]
# Index: []

# %%
duplicate = df[df.duplicated('Eviction_Address')]

# %%
duplicate.sort_values(by=['Docket_Number_'], ascending=False)
# Out:
#        Docket_Number_         Eviction_Address Executed_Date Property_Type  \
# 28729          496756      1311 COLLEGE AVENUE    2020-03-09   Residential
# 35328          496704  2500 UNIVERSITY AVEN UE    2020-03-03   Residential
# 54072          496564        530 W 30TH STREET    2020-03-04   Residential
# 46248          496507       2110 ARTHUR AVENUE    2020-02-13   Residential
# 36845          496411       2110 ARTHUR AVENUE    2020-02-26   Residential
# ...               ...                      ...           ...           ...
# 52592             619     1168 ROCKAWAY AVENUE    2017-08-03    Commercial
# 30561             594        38-21 12TH STREET    2017-12-13    Commercial
# 48882             106           81 HULL STREET    2017-09-27   Residential
# 37407             104           81 HULL STREET    2017-09-27   Residential
# 60105             103           81 HULL STREET    2017-09-27   Residential
#
#          Borough  Eviction_Postcode         Ejectment  \
# ...

# %%
duplicate[duplicate.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Docket_Number_, Eviction_Address, Executed_Date, Property_Type, Borough, Eviction_Postcode, Ejectment, Eviction/Legal_Possession, Latitude, Longitude, Neighborhood_Tabulation_Area]
# Index: []

# %%
duplicateDOCKET = df[df.duplicated(['Docket_Number_'],keep=False)]

# %%
duplicateDOCKET.sort_values(by=['Docket_Number_'], ascending=False)
# Out:
#        Docket_Number_     Eviction_Address Executed_Date Property_Type  \
# 10425          492575    1125 WYATT STREET    2019-09-26   Residential
# 5107           492575    1125 WYATT STREET    2019-12-03   Residential
# 25565          491588  750 GRAND CONCOURSE    2019-12-03   Residential
# 55976          491588  750 GRAND CONCOURSE    2019-08-02   Residential
# 45379          491588  750 GRAND CONCOURSE    2020-03-02   Residential
# ...               ...                  ...           ...           ...
# 26425            1021    56 VERMONT STREET    2017-10-31    Commercial
# 41965             999    713-715 HENRY ST.    2017-06-21   Residential
# 52664             999    713-715 HENRY ST.    2017-01-19   Residential
# 54806             796  320 BEACH 89 STREET    2017-06-15   Residential
# 50915             796    1212 OCEAN AVENUE    2017-02-06   Residential
#
#         Borough  Eviction_Postcode         Ejectment  \
# 10425     BRONX              10460  Not an Ejectment
# ...

# %%
df.loc[(df['Docket_Number_']== 89754)]
# Out:
#        Docket_Number_     Eviction_Address Executed_Date Property_Type  \
# 498             89754   1665 BRYANT AVENUE    2019-05-02   Residential
# 700             89754  115-27 122ND STREET    2018-09-28   Residential
# 26121           89754   1878 FOREST AVENUE    2019-01-25   Residential
#
#              Borough  Eviction_Postcode         Ejectment  \
# 498            BRONX              10460  Not an Ejectment
# 700           QUEENS              11420  Not an Ejectment
# 26121  STATEN ISLAND              10303  Not an Ejectment
#
#       Eviction/Legal_Possession   Latitude  Longitude  \
# 498                  Possession  40.834982 -73.886018
# 700                  Possession  40.676945 -73.816567
# 26121                Possession  40.625458 -74.151774
#
#                             Neighborhood_Tabulation_Area
# 498                                    Crotona Park East
# 700                                     South Ozone Park
# ...

# %%
df.shape
# Out:
# (67182, 11)
